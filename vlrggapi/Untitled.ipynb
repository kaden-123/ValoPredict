# %%
from scrapers import vlr_stats
import pandas as pd

# %%
stats = pd.DataFrame(vlr_stats("na", "60"))

# %%
stats
# Out:
#             player     org                         agents rounds_played  \
# 0           CHAROD   YFP.X       [cypher, clove, chamber]           269
# 1           terror    HAKI      [clove, reyna, brimstone]           238
# 2              Bob     FLY             [fade, sova, skye]           311
# 3          cuteasa  YDZ.GC          [viper, vyse, cypher]           209
# 4            colby    BLUE         [omen, chamber, viper]           229
# ..             ...     ...                            ...           ...
# 276         kacper    Eter        [vyse, cypher, killjoy]           325
# 277     Hyungwonho     AxA  [cypher, deadlock, brimstone]           203
# 278  SexyChristian     SAD             [sova, sage, fade]           418
# 279         Sixman     233             [jett, yoru, neon]           233
# 280        Tootsie  YDZ.GC         [sova, deadlock, fade]           322
#
#     rating average_combat_score kill_deaths kill_assists_survived_traded  \
# ...
