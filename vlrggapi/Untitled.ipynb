# %%
from scrapers import vlr_stats
import pandas as pd

# %%
vlr_stats("na", "60")
# Out:
# {'data': {'status': 200,
#   'segments': [{'player': 'CHAROD',
#     'org': 'YFP.X',
#     'agents': ['cypher', 'clove', 'chamber'],
#     'rounds_played': '269',
#     'rating': '1.37',
#     'average_combat_score': '295.1',
#     'kill_deaths': '1.48',
#     'kill_assists_survived_traded': '76%',
#     'average_damage_per_round': '177.6',
#     'kills_per_round': '1.04',
#     'assists_per_round': '0.19',
#     'first_kills_per_round': '0.19',
#     'first_deaths_per_round': '0.10',
#     'headshot_percentage': '40%',
#     'clutch_success_percentage': '21%'},
#    {'player': 'terror',
#     'org': 'HAKI',
#     'agents': ['viper', 'clove', 'reyna'],
#     'rounds_played': '282',
#     'rating': '1.29',
#     'average_combat_score': '268.7',
#     'kill_deaths': '1.31',
#     'kill_assists_survived_traded': '78%',
#     'average_damage_per_round': '179.6',
#     'kills_per_round': '0.98',
#     'assists_per_round': '0.29',
#     'first_kills_per_round': '0.07',
# ...
